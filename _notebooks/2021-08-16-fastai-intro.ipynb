# %% [markdown]
# # My Fast.ai Journey - Some Basic Theory
# > An brief overview of the theory of machine learning and its jargon.
#
# - badges: true
# - comments: true
# - categories: [fastbook, jupyter, fast.ai]

# %% [markdown]
# In this post, we'll look at the basic theory of machine learning and define a glossary of machine learning jargon.

# %% [markdown]
# ### What is Machine Learning?
#
# Let's start at the beginning, with the definition of *machine learning*, coined by an IBM researcher named Arthur Samuel. In his classic 1962 essay *Artificial Intelligence: A Frontier of Automation{% fn 1 %}*, he described the basic idea that instead of programming a computer with the exact steps to complete a certain task, *showing* the computer examples of completed tasks will allow it to figure out how to get there on its own!
#
# Samuels defined the basic idea of a **training loop** where a system is configured with a **set of parameters** and we have some way of *testing the effectiveness* of this configuration by observing the output of the system. We also need a way of automatically tweaking or **tuning** these parameters so that the output of the system keep improving. This, essentially, is a method using which a system can **learn** how to perform a task without any explicit instructions or programming.

# %%
#hide_input
from fastbook import gv
gv('''ordering=in
model[shape=box3d width=1 height=0.7 label=architecture]
inputs -> model -> predictions; parameters -> model; labels -> loss; predictions -> loss
loss -> parameters[constraint=false label=update]''')

# %% [markdown]
# <center><font size='2'>The training loop{% fn 2 %}</font></center>
#
# - The functional form or *structure* of the model is called its **architecture**.
# - The architecture has tunable knobs called **parameters**. **Weights** are a kind of parameter.
# - The **model** comprises the architecture and parameters.
# - The output of the model are its **predictions**, which are calculated from the **independent variables**, which is the data *without the labels*.
# - The measure of a model's performance is called the **loss**. The lower the loss, the better.
# - The loss depends on both the predictions and the labels (also known as **targets** or **dependent variables**).
# - The process of updating the parameters based on the loss is called **training**.
#
# When we are happy with our model's predictions *or* the loss value is sufficiently low, our training is complete. We then stop updating the parameters and calculating the loss and use the predictions directly; this is called **inference**.

# %% [markdown]
# ### Footnotes
#
# {{ '[Placeholder](placeholder)' | fndetail: 1 }}
# {{ '[Fastbook Chapter 1](https://github.com/fastai/fastbook/blob/master/01_intro.ipynb)' | fndetail: 2 }}
